# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### read data with regards to data layout & drop first row and data considering extrapolated values

# %%
df_worldpop = pd.read_excel('Resources\WorldPopulation.xlsx', sheet_name='Population', header = 1, usecols='E:CJ')

# %% [markdown]
# ### drop first(empty) row

# %%
df_worldpop = df_worldpop.drop(0)

# %%
df_worldpop
# Out:
#       Region         Country     Area      pop1950    pop1951    pop1952  \
# 1       Asia     Afghanistan   652230.0  8150368.0  8284473.0  8425333.0
# 2     Europe         Albania    27398.0  1227156.0  1254119.0  1282697.0
# 3     Africa         Algeria  2381741.0  8892718.0  9073304.0  9279525.0
# 4    Oceania  American Samoa      199.0    19100.0    19500.0    19300.0
# 5     Europe         Andorra      468.0     6176.0     6310.0     5866.0
# ..       ...             ...        ...        ...        ...        ...
# 224     Asia       West Bank     5640.0   771165.0   774512.0   777872.0
# 225   Africa  Western Sahara   266000.0     9057.0    10133.0    11336.0
# 226     Asia           Yemen   527968.0  4777089.0  4869125.0  4963829.0
# 227   Africa          Zambia   743398.0  2553000.0  2611000.0  2672000.0
# 228   Africa        Zimbabwe   386847.0  2853151.0  2950941.0  3080907.0
#
#        pop1953    pop1954    pop1955     pop1956  ...     pop2021     pop2022  \
# 1    8573217.0  8728408.0  8891209.0   9061938.0  ...  37524713.0  38415100.0
# 2    1314608.0  1352982.0  1392164.0   1434476.0  ...   3082448.0   3089575.0
# 3    9531710.0  9611093.0  9841851.0  10057133.0  ...  43596498.0  44195289.0
# 4      19200.0    19500.0    19800.0     20100.0  ...     53706.0     53629.0
# 5       5591.0     5503.0     6189.0      6221.0  ...     85565.0     85476.0
# ..         ...        ...        ...         ...  ...         ...         ...
# 224   781247.0   784637.0   788042.0    791462.0  ...   3112607.0   3166945.0
# 225    12682.0    14187.0    15872.0     17756.0  ...    668726.0    685311.0
# 226  5061153.0  5162494.0  5265327.0   5380106.0  ...  30319836.0  30909952.0
# 227  2734000.0  2800000.0  2869000.0   2941000.0  ...  17935659.0  18457738.0
# 228  3190967.0  3307273.0  3409017.0   3529739.0  ...  16148261.0  16460670.0
#
#         pop2023     pop2024     pop2025     pop2026     pop2027     pop2028  \
# 1    39311066.0  40211878.0  41117073.0  42025073.0  42935003.0  43845862.0
# 2     3095780.0   3100953.0   3104932.0   3107514.0   3108592.0   3108141.0
# 3    44768774.0  45317189.0  45841317.0  46342439.0  46821890.0  47281234.0
# 4       53541.0     53437.0     53316.0     53181.0     53030.0     52862.0
# 5       85370.0     85249.0     85112.0     84962.0     84799.0     84623.0
# ..          ...         ...         ...         ...         ...         ...
# 224   3221097.0   3274913.0   3328248.0   3381137.0   3433619.0   3485574.0
# 225    702012.0    718812.0    735697.0    752674.0    769751.0    786913.0
# 226  31496075.0  32076640.0  32650107.0  33219487.0  33787838.0  34353758.0
# 227  18993117.0  19542094.0  20104997.0  20682115.0  21273629.0  21879699.0
# 228  16768643.0  17071850.0  17370260.0  17664584.0  17955810.0  18244803.0
#
#         pop2029     pop2030
# 1    44756202.0  45664663.0
# 2     3106186.0   3102689.0
# 3    47722597.0  48148456.0
# 4       52678.0     52478.0
# 5       84437.0     84239.0
# ..          ...         ...
# 224   3536907.0   3587534.0
# 225    804144.0    821426.0
# 226  34915924.0  35472921.0
# 227  22500485.0  23136140.0
# 228  18532424.0  18819523.0
#
# [228 rows x 84 columns]

# %% [markdown]
# replace pop with empty string to simplify table head

# %%
df_worldpop.columns = df_worldpop.columns.str.replace('pop', '')

# %% [markdown]
# ### generate df of bools representing empty or non empty cells in the original df

# %%
mask = df_worldpop.isnull()

# %% [markdown]
# ### show empty check df

# %%
mask
# Out:
#      Region  Country  Area     1950   1951   1952   1953   1954   1955   1956  \
# 1     False    False   False  False  False  False  False  False  False  False
# 2     False    False   False  False  False  False  False  False  False  False
# 3     False    False   False  False  False  False  False  False  False  False
# 4     False    False   False  False  False  False  False  False  False  False
# 5     False    False   False  False  False  False  False  False  False  False
# ..      ...      ...     ...    ...    ...    ...    ...    ...    ...    ...
# 224   False    False   False  False  False  False  False  False  False  False
# 225   False    False   False  False  False  False  False  False  False  False
# 226   False    False   False  False  False  False  False  False  False  False
# 227   False    False   False  False  False  False  False  False  False  False
# 228   False    False   False  False  False  False  False  False  False  False
#
#      ...   2021   2022   2023   2024   2025   2026   2027   2028   2029   2030
# 1    ...  False  False  False  False  False  False  False  False  False  False
# 2    ...  False  False  False  False  False  False  False  False  False  False
# 3    ...  False  False  False  False  False  False  False  False  False  False
# 4    ...  False  False  False  False  False  False  False  False  False  False
# 5    ...  False  False  False  False  False  False  False  False  False  False
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 224  ...  False  False  False  False  False  False  False  False  False  False
# 225  ...  False  False  False  False  False  False  False  False  False  False
# 226  ...  False  False  False  False  False  False  False  False  False  False
# 227  ...  False  False  False  False  False  False  False  False  False  False
# 228  ...  False  False  False  False  False  False  False  False  False  False
#
# [228 rows x 84 columns]

# %% [markdown]
# ### check if there are any values in each row //looking for bools ("1" or "true")

# %%
emptymask = mask.any(axis = 1)

# %%
emptymask
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# Length: 228, dtype: bool

# %% [markdown]
# ###  use compressed mask to finally check for any empty values in a easy readable form

# %%
df_worldpop[emptymask]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Area  , 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030]
# Index: []
#
# [0 rows x 84 columns]

# %% [markdown]
# TODO:
#     suche nach NullWerte
#     bestimme min, max, median
#     suche nach doppelte Einträge
#     DT abändern (Region kategoricalstring) nach dem merge
#     zweiten DS einlesen

# %% [markdown]
# ### Check if Countrys are unique

# %%
pd.Series(df_worldpop["Country"]).is_unique
# Out:
# True

# %% [markdown]
# ### use describe as a placeholder little to no use at this point

# %%
print(df_worldpop.describe())
# Out:
#              Area            1950          1951          1952          1953  \
# count  2.280000e+02  2.280000e+02  2.280000e+02  2.280000e+02  2.280000e+02
# mean   5.792173e+05  1.121767e+07  1.138123e+07  1.156462e+07  1.176313e+07
# std    1.720351e+06  4.701986e+07  4.754429e+07  4.823644e+07  4.905736e+07
# min    2.000000e+00  2.028000e+03  2.040000e+03  2.053000e+03  2.066000e+03
# 25%    4.854250e+03  1.127918e+05  1.151795e+05  1.176912e+05  1.203490e+05
# 50%    8.253700e+04  1.705811e+06  1.736012e+06  1.762424e+06  1.794953e+06
# 75%    4.283918e+05  6.261032e+06  6.381841e+06  6.518334e+06  6.706298e+06
# max    1.637774e+07  5.625798e+08  5.671008e+08  5.745363e+08  5.841914e+08
#
#                1954          1955          1956          1957          1958  \
# count  2.280000e+02  2.280000e+02  2.280000e+02  2.280000e+02  2.280000e+02
# mean   1.197434e+07  1.220176e+07  1.243501e+07  1.268075e+07  1.292973e+07
# std    4.993869e+07  5.090936e+07  5.190744e+07  5.300301e+07  5.407835e+07
# min    2.079000e+03  2.092000e+03  2.105000e+03  2.118000e+03  2.132000e+03
# 25%    1.232002e+05  1.263135e+05  1.297668e+05  1.336255e+05  1.380422e+05
# 50%    1.833393e+06  1.873836e+06  1.912198e+06  1.960418e+06  2.025899e+06
# 75%    6.862322e+06  6.968664e+06  7.024331e+06  7.127270e+06  7.267123e+06
# max    5.947248e+08  6.067297e+08  6.191359e+08  6.332146e+08  6.467031e+08
#
#        ...          2021          2022          2023          2024  \
# count  ...  2.280000e+02  2.280000e+02  2.280000e+02  2.280000e+02
# mean   ...  3.377853e+07  3.409556e+07  3.440831e+07  3.471642e+07
# std    ...  1.332295e+08  1.341000e+08  1.349417e+08  1.357533e+08
# min    ...  5.284000e+03  5.220000e+03  5.157000e+03  5.093000e+03
# 25%    ...  6.090330e+05  6.149932e+05  6.198970e+05  6.238718e+05
# 50%    ...  5.837019e+06  5.900861e+06  5.997996e+06  6.094441e+06
# 75%    ...  2.305060e+07  2.338178e+07  2.372880e+07  2.409216e+07
# max    ...  1.387641e+09  1.390212e+09  1.392244e+09  1.393719e+09
#
#                2025          2026          2027          2028          2029  \
# count  2.280000e+02  2.280000e+02  2.280000e+02  2.280000e+02  2.280000e+02
# mean   3.501961e+07  3.531823e+07  3.561252e+07  3.590221e+07  3.618719e+07
# std    1.365340e+08  1.372852e+08  1.380084e+08  1.387040e+08  1.393727e+08
# min    5.030000e+03  4.966000e+03  4.903000e+03  4.840000e+03  4.776000e+03
# 25%    6.276175e+05  6.311352e+05  6.330275e+05  6.356018e+05  6.364588e+05
# 50%    6.190106e+06  6.229166e+06  6.219232e+06  6.195466e+06  6.168318e+06
# 75%    2.472754e+07  2.528618e+07  2.562652e+07  2.588585e+07  2.605293e+07
# max    1.396046e+09  1.409417e+09  1.422588e+09  1.435543e+09  1.448266e+09
#
#                2030
# count  2.280000e+02
# mean   3.646735e+07
# std    1.400152e+08
# min    4.713000e+03
# 25%    6.371095e+05
# 50%    6.183295e+06
# 75%    2.621396e+07
# max    1.460743e+09
#
# [8 rows x 82 columns]

# %% [markdown]
# #### loop through col and count rows with value "0" // ie check DF for zeroes

# %%
num = 0
for i in df_worldpop.columns:
   num += df_worldpop[i][df_worldpop[i]==0].count()
num
# Out:
# 0

# %% [markdown]
# ## try to read csv / no clue what the problem is / leave it for later

# %%
df_deathstats = pd.read_csv('resources\annual-number-of-deaths-by-cause.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df_deathstats = pd.read_csv('resources\annual-number-of-deaths-by-cause.csv')
#
# File ~\miniconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:1729, in TextFileReader._make_engine(self, f, engine)
#    1727     is_text = False
#    1728     mode = "rb"
# -> 1729 self.handles = get_handle(
#    1730     f,
#    1731     mode,
#    1732     encoding=self.options.get("encoding", None),
#    1733     compression=self.options.get("compression", None),
#    1734     memory_map=self.options.get("memory_map", False),
#    1735     is_text=is_text,
#    1736     errors=self.options.get("encoding_errors", "strict"),
#    1737     storage_options=self.options.get("storage_options", None),
#    1738 )
#    1739 assert self.handles is not None
#    1740 f = self.handles.handle
#
# File ~\miniconda3\lib\site-packages\pandas\io\common.py:857, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     852 elif isinstance(handle, str):
#     853     # Check whether the filename is to be opened in binary mode.
#     854     # Binary mode does not support 'encoding' and 'newline'.
#     855     if ioargs.encoding and "b" not in ioargs.mode:
#     856         # Encoding
# --> 857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#     860             encoding=ioargs.encoding,
#     861             errors=errors,
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
#     866         handle = open(handle, ioargs.mode)
#
# OSError: [Errno 22] Invalid argument: 'resources\x07nnual-number-of-deaths-by-cause.csv'

# %% [markdown]
# ### load deathdata under new file name as workaround

# %%
df_deathstats = pd.read_csv('resources\deathdata.csv')

# %%
df_deathstats
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 7268     Zimbabwe  ZWE  2015                                          NaN
# 7269     Zimbabwe  ZWE  2016                                          NaN
# 7270     Zimbabwe  ZWE  2017                                          NaN
# 7271     Zimbabwe  ZWE  2018                                          NaN
# 7272     Zimbabwe  ZWE  2019                                          NaN
#
#       Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                                2933.0
# 1                                                2731.0
# 2                                                2460.0
# 3                                                2327.0
# 4                                                2254.0
# ...                                                 ...
# 7268                                             1439.0
# 7269                                             1457.0
# 7270                                             1460.0
# 7271                                             1450.0
# 7272                                             1450.0
#
#       Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)  \
# 0                                                1402.0
# 1                                                1424.0
# 2                                                1449.0
# 3                                                1508.0
# 4                                                1544.0
# ...                                                 ...
# 7268                                              754.0
# 7269                                              767.0
# 7270                                              781.0
# 7271                                              795.0
# 7272                                              812.0
#
#       Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)  \
# 0                                                 450.0
# 1                                                 455.0
# 2                                                 460.0
# 3                                                 473.0
# 4                                                 482.0
# ...                                                 ...
# 7268                                              215.0
# 7269                                              219.0
# 7270                                              223.0
# 7271                                              227.0
# 7272                                              232.0
#
#       Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)  \
# 0                                                2488.0
# 1                                                2277.0
# 2                                                2040.0
# 3                                                1846.0
# 4                                                1705.0
# ...                                                 ...
# 7268                                             3019.0
# 7269                                             3056.0
# 7270                                             2990.0
# 7271                                             2918.0
# 7272                                             2884.0
#
#       Deaths - Malaria - Sex: Both - Age: All Ages (Number)  \
# 0                                                 393.0
# 1                                                 255.0
# 2                                                 239.0
# 3                                                 390.0
# 4                                                  94.0
# ...                                                 ...
# 7268                                             2518.0
# 7269                                             2050.0
# 7270                                             2116.0
# 7271                                             2088.0
# 7272                                             2068.0
#
#       Deaths - Drowning - Sex: Both - Age: All Ages (Number)  ...  \
# 0                                                2127.0       ...
# 1                                                1973.0       ...
# 2                                                1852.0       ...
# 3                                                1775.0       ...
# 4                                                1716.0       ...
# ...                                                 ...       ...
# 7268                                              770.0       ...
# 7269                                              801.0       ...
# 7270                                              818.0       ...
# 7271                                              825.0       ...
# 7272                                              827.0       ...
#
#       Deaths - Chronic kidney disease - Sex: Both - Age: All Ages (Number)  \
# 0                                                4490.0
# 1                                                4534.0
# 2                                                4597.0
# 3                                                4785.0
# 4                                                4846.0
# ...                                                 ...
# 7268                                             2108.0
# 7269                                             2160.0
# 7270                                             2196.0
# 7271                                             2240.0
# 7272                                             2292.0
#
#       Deaths - Poisonings - Sex: Both - Age: All Ages (Number)  \
# 0                                                 513.0
# 1                                                 495.0
# 2                                                 483.0
# 3                                                 483.0
# 4                                                 482.0
# ...                                                 ...
# 7268                                              381.0
# 7269                                              393.0
# 7270                                              398.0
# 7271                                              400.0
# 7272                                              405.0
#
#       Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Number)  \
# 0                                                2439.0
# 1                                                2231.0
# 2                                                1998.0
# 3                                                1805.0
# 4                                                1667.0
# ...                                                 ...
# 7268                                             2990.0
# 7269                                             3027.0
# 7270                                             2962.0
# 7271                                             2890.0
# 7272                                             2855.0
#
#       Terrorism (deaths)  \
# 0                 1199.0
# 1                 1092.0
# 2                 1065.0
# 3                 1525.0
# 4                 3521.0
# ...                  ...
# 7268                 NaN
# 7269                 NaN
# 7270                 0.0
# 7271                 NaN
# 7272                 NaN
#
#       Deaths - Road injuries - Sex: Both - Age: All Ages (Number)  \
# 0                                                7425.0
# 1                                                7355.0
# 2                                                7290.0
# 3                                                7432.0
# 4                                                7494.0
# ...                                                 ...
# 7268                                             2373.0
# 7269                                             2436.0
# 7270                                             2473.0
# 7271                                             2509.0
# 7272                                             2554.0
#
#       Deaths - Chronic respiratory diseases - Sex: Both - Age: All Ages (Number)  \
# 0                                                7222.0
# 1                                                7143.0
# 2                                                7045.0
# 3                                                6916.0
# 4                                                6878.0
# ...                                                 ...
# 7268                                             2751.0
# 7269                                             2788.0
# 7270                                             2818.0
# 7271                                             2849.0
# 7272                                             2891.0
#
#       Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: All Ages (Number)  \
# 0                                                3346.0
# 1                                                3316.0
# 2                                                3291.0
# 3                                                3318.0
# 4                                                3353.0
# ...                                                 ...
# 7268                                             1956.0
# 7269                                             1962.0
# 7270                                             2007.0
# 7271                                             2030.0
# 7272                                             2065.0
#
#       Deaths - Digestive diseases - Sex: Both - Age: All Ages (Number)  \
# 0                                                6458.0
# 1                                                6408.0
# 2                                                6358.0
# 3                                                6370.0
# 4                                                6398.0
# ...                                                 ...
# 7268                                             4202.0
# 7269                                             4264.0
# 7270                                             4342.0
# 7271                                             4377.0
# 7272                                             4437.0
#
#       Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)  \
# 0                                                 481.0
# 1                                                 462.0
# 2                                                 448.0
# 3                                                 448.0
# 4                                                 445.0
# ...                                                 ...
# 7268                                              632.0
# 7269                                              648.0
# 7270                                              654.0
# 7271                                              657.0
# 7272                                              662.0
#
#       Deaths - Acute hepatitis - Sex: Both - Age: All Ages (Number)
# 0                                                3437.0
# 1                                                3005.0
# 2                                                2663.0
# 3                                                2365.0
# 4                                                2264.0
# ...                                                 ...
# 7268                                              146.0
# 7269                                              146.0
# 7270                                              144.0
# 7271                                              139.0
# 7272                                              136.0
#
# [7273 rows x 36 columns]

# %% [markdown]
# ### for some countrys we are missing data / lets replace them with "noData" for now

# %%
df_deathstats.fillna('noData', inplace = True)

# %%
df_deathstats
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 7268     Zimbabwe  ZWE  2015                                       noData
# 7269     Zimbabwe  ZWE  2016                                       noData
# 7270     Zimbabwe  ZWE  2017                                       noData
# 7271     Zimbabwe  ZWE  2018                                       noData
# 7272     Zimbabwe  ZWE  2019                                       noData
#
#      Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                                2933.0
# 1                                                2731.0
# 2                                                2460.0
# 3                                                2327.0
# 4                                                2254.0
# ...                                                 ...
# 7268                                             1439.0
# 7269                                             1457.0
# 7270                                             1460.0
# 7271                                             1450.0
# 7272                                             1450.0
#
#      Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)  \
# 0                                                1402.0
# 1                                                1424.0
# 2                                                1449.0
# 3                                                1508.0
# 4                                                1544.0
# ...                                                 ...
# 7268                                              754.0
# 7269                                              767.0
# 7270                                              781.0
# 7271                                              795.0
# 7272                                              812.0
#
#      Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)  \
# 0                                                 450.0
# 1                                                 455.0
# 2                                                 460.0
# 3                                                 473.0
# 4                                                 482.0
# ...                                                 ...
# 7268                                              215.0
# 7269                                              219.0
# 7270                                              223.0
# 7271                                              227.0
# 7272                                              232.0
#
#      Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)  \
# 0                                                2488.0
# 1                                                2277.0
# 2                                                2040.0
# 3                                                1846.0
# 4                                                1705.0
# ...                                                 ...
# 7268                                             3019.0
# 7269                                             3056.0
# 7270                                             2990.0
# 7271                                             2918.0
# 7272                                             2884.0
#
#      Deaths - Malaria - Sex: Both - Age: All Ages (Number)  \
# 0                                                 393.0
# 1                                                 255.0
# 2                                                 239.0
# 3                                                 390.0
# 4                                                  94.0
# ...                                                 ...
# 7268                                             2518.0
# 7269                                             2050.0
# 7270                                             2116.0
# 7271                                             2088.0
# 7272                                             2068.0
#
#      Deaths - Drowning - Sex: Both - Age: All Ages (Number)  ...  \
# 0                                                2127.0      ...
# 1                                                1973.0      ...
# 2                                                1852.0      ...
# 3                                                1775.0      ...
# 4                                                1716.0      ...
# ...                                                 ...      ...
# 7268                                              770.0      ...
# 7269                                              801.0      ...
# 7270                                              818.0      ...
# 7271                                              825.0      ...
# 7272                                              827.0      ...
#
#      Deaths - Chronic kidney disease - Sex: Both - Age: All Ages (Number)  \
# 0                                                4490.0
# 1                                                4534.0
# 2                                                4597.0
# 3                                                4785.0
# 4                                                4846.0
# ...                                                 ...
# 7268                                             2108.0
# 7269                                             2160.0
# 7270                                             2196.0
# 7271                                             2240.0
# 7272                                             2292.0
#
#      Deaths - Poisonings - Sex: Both - Age: All Ages (Number)  \
# 0                                                 513.0
# 1                                                 495.0
# 2                                                 483.0
# 3                                                 483.0
# 4                                                 482.0
# ...                                                 ...
# 7268                                              381.0
# 7269                                              393.0
# 7270                                              398.0
# 7271                                              400.0
# 7272                                              405.0
#
#      Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Number)  \
# 0                                                2439.0
# 1                                                2231.0
# 2                                                1998.0
# 3                                                1805.0
# 4                                                1667.0
# ...                                                 ...
# 7268                                             2990.0
# 7269                                             3027.0
# 7270                                             2962.0
# 7271                                             2890.0
# 7272                                             2855.0
#
#      Terrorism (deaths)  \
# 0                1199.0
# 1                1092.0
# 2                1065.0
# 3                1525.0
# 4                3521.0
# ...                 ...
# 7268             noData
# 7269             noData
# 7270                0.0
# 7271             noData
# 7272             noData
#
#      Deaths - Road injuries - Sex: Both - Age: All Ages (Number)  \
# 0                                                7425.0
# 1                                                7355.0
# 2                                                7290.0
# 3                                                7432.0
# 4                                                7494.0
# ...                                                 ...
# 7268                                             2373.0
# 7269                                             2436.0
# 7270                                             2473.0
# 7271                                             2509.0
# 7272                                             2554.0
#
#      Deaths - Chronic respiratory diseases - Sex: Both - Age: All Ages (Number)  \
# 0                                                7222.0
# 1                                                7143.0
# 2                                                7045.0
# 3                                                6916.0
# 4                                                6878.0
# ...                                                 ...
# 7268                                             2751.0
# 7269                                             2788.0
# 7270                                             2818.0
# 7271                                             2849.0
# 7272                                             2891.0
#
#      Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: All Ages (Number)  \
# 0                                                3346.0
# 1                                                3316.0
# 2                                                3291.0
# 3                                                3318.0
# 4                                                3353.0
# ...                                                 ...
# 7268                                             1956.0
# 7269                                             1962.0
# 7270                                             2007.0
# 7271                                             2030.0
# 7272                                             2065.0
#
#      Deaths - Digestive diseases - Sex: Both - Age: All Ages (Number)  \
# 0                                                6458.0
# 1                                                6408.0
# 2                                                6358.0
# 3                                                6370.0
# 4                                                6398.0
# ...                                                 ...
# 7268                                             4202.0
# 7269                                             4264.0
# 7270                                             4342.0
# 7271                                             4377.0
# 7272                                             4437.0
#
#      Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)  \
# 0                                                 481.0
# 1                                                 462.0
# 2                                                 448.0
# 3                                                 448.0
# 4                                                 445.0
# ...                                                 ...
# 7268                                              632.0
# 7269                                              648.0
# 7270                                              654.0
# 7271                                              657.0
# 7272                                              662.0
#
#      Deaths - Acute hepatitis - Sex: Both - Age: All Ages (Number)
# 0                                                3437.0
# 1                                                3005.0
# 2                                                2663.0
# 3                                                2365.0
# 4                                                2264.0
# ...                                                 ...
# 7268                                              146.0
# 7269                                              146.0
# 7270                                              144.0
# 7271                                              139.0
# 7272                                              136.0
#
# [7273 rows x 36 columns]

# %%
print(df_deathstats.describe())
# Out:
#               Year
# count  7273.000000
# mean   2004.425134
# std       8.623572
# min    1990.000000
# 25%    1997.000000
# 50%    2004.000000
# 75%    2012.000000
# max    2019.000000

# %%
df_deathstats.std

# %%
df_deathstats.mean

# %%
df_deathstats.dtypes
# Out:
# Entity                                                                                      object
# Code                                                                                        object
# Year                                                                                         int64
# Number of executions (Amnesty International)                                                object
# Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                    object
# Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)       object
# Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)                           object
# Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)                      object
# Deaths - Malaria - Sex: Both - Age: All Ages (Number)                                       object
# Deaths - Drowning - Sex: Both - Age: All Ages (Number)                                      object
# Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)                        object
# Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)                            object
# Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)                                      object
# Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)                            object
# Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number)                                  object
# Deaths - Cardiovascular diseases - Sex: Both - Age: All Ages (Number)                       object
# Deaths - Lower respiratory infections - Sex: Both - Age: All Ages (Number)                  object
# Deaths - Neonatal disorders - Sex: Both - Age: All Ages (Number)                            object
# Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)                         object
# Deaths - Self-harm - Sex: Both - Age: All Ages (Number)                                     object
# Deaths - Exposure to forces of nature - Sex: Both - Age: All Ages (Number)                  object
# Deaths - Diarrheal diseases - Sex: Both - Age: All Ages (Number)                            object
# Deaths - Environmental heat and cold exposure - Sex: Both - Age: All Ages (Number)          object
# Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)                                     object
# Deaths - Conflict and terrorism - Sex: Both - Age: All Ages (Number)                        object
# Deaths - Diabetes mellitus - Sex: Both - Age: All Ages (Number)                             object
# Deaths - Chronic kidney disease - Sex: Both - Age: All Ages (Number)                        object
# Deaths - Poisonings - Sex: Both - Age: All Ages (Number)                                    object
# Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Number)                   object
# Terrorism (deaths)                                                                          object
# Deaths - Road injuries - Sex: Both - Age: All Ages (Number)                                 object
# Deaths - Chronic respiratory diseases - Sex: Both - Age: All Ages (Number)                  object
# Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: All Ages (Number)    object
# Deaths - Digestive diseases - Sex: Both - Age: All Ages (Number)                            object
# Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)                object
# Deaths - Acute hepatitis - Sex: Both - Age: All Ages (Number)                               object
# dtype: object
